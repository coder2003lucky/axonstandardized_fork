# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# save voltages for viz    
target_volts = np.load('volt_collector.npy')
for i in range(len(target_volts)):
    plt.figure()
    plt.plot(target_volts[i,:])
