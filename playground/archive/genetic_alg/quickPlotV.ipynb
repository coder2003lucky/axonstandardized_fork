# %%
import numpy as np
import matplotlib.pyplot as plt


targV = np.genfromtxt("targetVolts.csv", delimiter = ',')

for i in range(targV.shape[0]):
    plt.figure()
    plt.plot(targV[i])

# %%
import h5py
test_stim1_name = '65'
test_stim2_name = '51_2'
run_volts_path = '../gen_alg_GPU/'
stims_path = run_volts_path+'/stims/allen_data_stims_10000.hdf5'
stims_hdf5 = h5py.File(stims_path, 'r')
objectives_file = h5py.File('../gen_alg_GPU/python/objectives/multi_stim_bbp_full_allen_gpu_tune_18_stims.hdf5', 'r')
opt_stim_name_list = objectives_file['opt_stim_name_list'][:]
opt_stim_list = [e.decode('ascii') for e in opt_stim_name_list]

# %%
# Out:
#   File "<ipython-input-4-fc5491e812b6>", line 1
#     stims_hdf5.keys()[]
#                       ^
# SyntaxError: invalid syntax

# %%
opt_stim_list
# Out:
# ['4',
#  '23',
#  '22',
#  '48_3',
#  '53_3',
#  '51_1',
#  '58',
#  '48_1',
#  '66',
#  '48_2',
#  '44',
#  '16',
#  '38',
#  '28',
#  '13',
#  '18',
#  '15',
#  '14']
