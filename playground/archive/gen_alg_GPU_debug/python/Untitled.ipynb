# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
targV = np.load('target.npy')
print(targV.shape)
for i in range(targV.shape[0]):
    plt.figure()
    plt.plot(targV[i])
# Out:
# (20, 10000)

# %%
expV = np.load("volt_collector.npy")
expV.shape
# Out:
# (20, 10000)

# %%
for i in range(expV.shape[0]):
    plt.figure()
    plt.plot(expV[i])

# %%
orig_params = [8.00000000e-05, 2.61450000e-02, 4.22600000e-03, 8.00000000e-05,
 1.43000000e-04, 3.13796800e+00, 8.92590000e-02, 2.91000000e-03,
 6.82700000e-03, 7.10400000e-03, 9.90000000e-04, 9.73538000e-01,
 1.02194500e+00, 2.87198731e+02, 8.75200000e-03, 6.09000000e-04,
 3.03472000e-01, 8.40700000e-03, 9.94000000e-04, 9.83955000e-01,
 8.00000000e-05, 2.10485284e+02, 3.33000000e-04, 3.00000000e-05]
