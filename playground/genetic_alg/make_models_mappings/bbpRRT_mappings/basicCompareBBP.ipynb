# %%
import numpy as np
import struct
import matplotlib.pyplot as plt

def nrnMread(fileName):
    f = open(fileName, "rb")
    nparam = struct.unpack('i', f.read(4))[0]
    typeFlg = struct.unpack('i', f.read(4))[0]
    return np.fromfile(f,np.double)


# volts = nrnMread("../Data/VHotP0.dat")
# plt.plot(volts, label="NeuroGPU")

target_volts = np.genfromtxt("./Data/bbp_RmpRiTau_targV.csv", delimiter=",")[0]
plt.plot(target_volts, color="Red", label="target")
plt.legend()

plt.figure()
target_volts = np.genfromtxt("./Data/bbp_RmpRiTau_targV.csv", delimiter=",")[10]
plt.plot(target_volts, color="Red", label="target")

plt.figure()
target_volts = np.genfromtxt("./Data/bbp_RmpRiTau_targV.csv", delimiter=",")[2]
plt.plot(target_volts, color="Red", label="target")
