# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
volts = np.genfromtxt("volts4compare.csv",delimiter=",")
# for i in range(11):
#     plt.figure()
#     plt.plot(volts[i])

# %%
plt.plot(volts[7])
