# %%
import numpy as np 
import matplotlib.pyplot as plt
import h5py

# %%
file = np.genfromtxt("targetVolts.csv", delimiter=",")


for elem in file:
    plt.figure()
    plt.plot(elem, color="blue")
