# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py

# %%
targV = np.genfromtxt('targetVolts_zeroed.csv', delimiter=',')
targV.shape
target_volts_path = '../results/485835016/target_volts_485835016_passive.hdf5'
target_volts_hdf5  = h5py.File(target_volts_path) 
ground_truth = [target_volts_hdf5[s][:] for s in target_volts_hdf5.keys()]
target_volts_hdf5.close()

# %%
for i in range(20):
    plt.figure()
    plt.plot(targV[i])
    plt.plot(ground_truth[i], color='red')
